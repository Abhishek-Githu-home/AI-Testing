# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhishek-Githu-home/AI-Testing/blob/main/Colab_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai -q
import openai

from google.colab import userdata
api_key = input("Enter the OpenAI API secret Key: ")

client = openai.OpenAI(api_key=api_key)
def get_answer():
  user_question = input("\nAsk a question: ")
  try:
    response = client.chat.completions.create(model = "gpt-3.5-turbo", messages = [{"role" : "user", "content": user_question}])
    answer = response.choices[0].message.content
  except Exception as e:
    print(f"An error occured: {e}")
print('--- The first Question ---')
get_answer()
print("\n ---The second Question ---")
get_answer()
# Out:
# Enter the OpenAI API secret Key: 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
# --- sample Question 1 ---
